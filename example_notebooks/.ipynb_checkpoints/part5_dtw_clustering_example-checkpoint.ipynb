# %%
# pip install -i https://test.pypi.org/simple/ dtwhaclustering -U

# %%
from dtwhaclustering.dtw_analysis import dtw_signal_pairs, dtw_clustering, plot_signals, shuffle_signals, plot_cluster
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
from dtaidistance import dtw
from scipy.cluster.hierarchy import fcluster

from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering


# %matplotlib inline 

import matplotlib
fontsize = 26
# font = {'family': 'Times',
#         'weight': 'bold',
#         'size': fontsize}

# matplotlib.rc('font', **font)
plt.rcParams["figure.figsize"] = (12, 6)
plt.style.use('ggplot')
matplotlib.rcParams['pdf.fonttype'] = 42

plt.rc('font', size=fontsize)  # controls default text size
plt.rc('axes', titlesize=fontsize)  # fontsize of the title
plt.rc('axes', labelsize=fontsize)  # fontsize of the x and y labels
plt.rc('xtick', labelsize=fontsize-10)  # fontsize of the x tick labels
plt.rc('ytick', labelsize=fontsize-10)  # fontsize of the y tick labels
plt.rc('legend', fontsize=fontsize)  # fontsize of the legend

# %% [markdown]
# ### Create 5 signals

# %%
np.random.seed(0)
# sampling parameters
fs = 100   # sampling rate, in Hz
T  = 1      # duration, in seconds
N  = T * fs # duration, in samples
M  = 5      # number of sources
R  = 3      # number of copies
MR = M * R 


# time variable
t = np.linspace(0, T, N)

S1 = np.sin(2 * np.pi * t * 7)
S2 = signal.sawtooth(2 * np.pi * t * 5)
S3 = np.abs(np.cos(2 * np.pi * t * 3)) - 0.5
S4 = np.sign(np.sin(2 * np.pi * t * 8))
S5 = np.random.randn(N)

time_series = np.array([S1, S2, S3, S4, S5])
time_series.shape
# Out:
# (5, 100)

# %%
fig, ax = plot_signals(time_series)
# plt.show()
plt.savefig("Figures/base_functions.pdf", bbox_inches='tight')

# %%
dtwsig = dtw_signal_pairs(S1, S2, labels=['S1', 'S2'])
matplotlib.rcParams['pdf.fonttype'] = 42
distance,_,_ = dtwsig.plot_warping_path(figsize=(10,8))
print(f"DTW distance between signals: {distance:.4f}")

# plt.show()
plt.savefig("Figures/warping_path_s1_s2.pdf", bbox_inches='tight')
# Out:
# DTW distance between signals: 5.1600

# %% [markdown]
# ### Add noise and make 3 copies of each signal

# %%
SNR = 0.2
X0 = np.tile(S1, (R, 1)) + np.random.randn(R, N) * SNR 
X1 = np.tile(S2, (R, 1)) + np.random.randn(R, N) * SNR 
X2 = np.tile(S3, (R, 1)) + np.random.randn(R, N) * SNR 
X3 = np.tile(S4, (R, 1)) + np.random.randn(R, N) * SNR 
X4 = np.tile(S5, (R, 1)) + np.random.randn(R, N) * SNR 
X = np.concatenate((X0, X1, X2, X3, X4))

# %%
## instantiate the class
# dtw_cluster2 = dtw_clustering(X)
# dtw_cluster2.plot_signals(figsize=(10,12))
# plt.show()
color = ['C0']*3+['C1']*3+['C2']*3+['C3']*3+['C4']*3
fig, ax = plot_signals(X,figsize=(10,20), color=color)
plt.show()

# %% [markdown]
# Now, we have 15 signals in total. Let us also randomly make these signals distributed in geographical space by assigning them longitudes and latitudes. We assume that the signals with similar waveforms are geographically co-located.

# %% [markdown]
# ```
# S0 variants (S0, S1, S2) -> xrange(0-3) yrange(7-10)
# S1 variants (S3, S4, S5) -> xrange(1-4) yrange(3-5)
# S2 variants (S6, S7, S8) -> xrange(4-8) yrange(4-6)
# S3 variants (S9, S10, S11) -> xrange(5-10) yrange(0-4)
# S4 variants (S12, S13, S14) -> xrange(5-9) yrange(6-9)
# ```

# %%
S0_lons = np.random.uniform(0, 3, 3)
S0_lats = np.random.uniform(7, 10, 3)

S1_lons = np.random.uniform(1, 4, 3)
S1_lats = np.random.uniform(3, 5, 3)

S2_lons = np.random.uniform(4, 8, 3)
S2_lats = np.random.uniform(4, 6, 3)

S3_lons = np.random.uniform(5, 10, 3)
S3_lats = np.random.uniform(0, 4, 3)

S3_lons = np.random.uniform(5, 10, 3)
S3_lats = np.random.uniform(0, 4, 3)

S4_lons = np.random.uniform(5, 9, 3)
S4_lats = np.random.uniform(6, 9, 3)

# %%
lons = np.concatenate((S0_lons, S1_lons, S2_lons, S3_lons, S4_lons))
lats = np.concatenate((S0_lats, S1_lats, S2_lats, S3_lats, S4_lats))

# %%
plot_cluster(lons,lats)
# plt.show()
plt.savefig("Figures/signals_locations.pdf", bbox_inches='tight')

# %% [markdown]
# ### Reshuffle the noisy signals
# - to ensure that the algorithm don't remember the order

# %%
shuffled_idx, shuffled_matrix = shuffle_signals(X, labels=[], plot_signals=False, figsize=(10, 20))
shuffled_lons = lons[shuffled_idx]
shuffled_lats = lats[shuffled_idx]
# plt.show()
# plt.savefig("Figures/shuffled_signals.pdf", bbox_inches='tight')
# labels = np.array([f"S{i}" for i in range(1,16)])
labels = np.array(['S1a', 'S1b', 'S1c','S2a', 'S2b', 'S2c','S3a', 'S3b', 'S3c','S4a', 'S4b', 'S4c','S5a', 'S5b', 'S5c'])
newlabels = labels[shuffled_idx]

# %%
newlabels
# Out:
# array(['S4a', 'S2b', 'S5b', 'S4c', 'S5c', 'S1a', 'S4b', 'S1b', 'S3c',
#        'S1c', 'S2a', 'S3b', 'S5a', 'S2c', 'S3a'], dtype='<U3')

# %%
len(newlabels)
# Out:
# 15

# %%
color = np.array(color)
color = color[shuffled_idx]
fig, ax = plot_signals(shuffled_matrix,figsize=(10,20), color=color, labels=newlabels)
plt.savefig("Figures/shuffled_signals.pdf", bbox_inches='tight')

# %% [markdown]
# ### Reshuffled signal names

# %%
# instantiate the class
dtw_cluster2 = dtw_clustering(shuffled_matrix, labels=newlabels, longitudes=shuffled_lons, latitudes=shuffled_lats)

# dtw_cluster2 = dtw_clustering(X, labels=labels_orig, longitudes=lons, latitudes=lats)

# %%
## instantiate the class
dtw_cluster2.plot_dendrogram(annotate_above=3, max_d = 3,xlabel="Signals", figname="Figures/example_dtw_cluster.png")
plt.show()
# Out:
# The compiled dtaidistance C-OMP library is not available.
# Use Python's multiprocessing library for parellelization (use_mp=True).
# See the documentation for alternative installation options.
# The compiled dtaidistance C-OMP library is not available.
# Using the Python multiprocessing library instead (use_mp=True).
# See the documentation for alternative installation options.
#
#  93%|█████████▎| 14/15 [00:00<00:00, 14402.81it/s]

# %% [markdown]
# In the above dendrogram, we manually selected the threshold distance to be 3 to find the best clusters

# %%
dtw_cluster2.plot_cluster_xymap(dtw_distance=3, figname=None, xlabel='', ylabel='', fontsize=40, markersize=200, tickfontsize=30)
plt.savefig("Figures/signals_cluster_xy_map.pdf", bbox_inches='tight', edgecolors='black', linewidths=5)
# Out:
# /Users/utpalkumar50/GoogleDrive/ManuscriptsWriting1/EastCoastStudy/Codes/example_notebooks/dtwhaclustering/dtw_analysis.py:340: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ))-1, int(self.longitudes.max())+1, xtickstep), fontsize=tickfontsize)
# /Users/utpalkumar50/GoogleDrive/ManuscriptsWriting1/EastCoastStudy/Codes/example_notebooks/dtwhaclustering/dtw_analysis.py:342: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ))-1, int(self.latitudes.max())+1, xtickstep), fontsize=tickfontsize)
# /Users/utpalkumar50/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolors" which is no longer supported as of 3.3 and will become an error two minor releases later
#
# /Users/utpalkumar50/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "linewidths" which is no longer supported as of 3.3 and will become an error two minor releases later

# %% [markdown]
# ### plot only truncated dendrogram, which only shows the last truncate_p=5 out of our all merges

# %%
## instantiate the class
dtw_cluster2.plot_dendrogram(annotate_above=3,xlabel="Signals") 
# plt.show()
plt.savefig("Figures/dendrogram_signals.pdf", bbox_inches='tight')

# %% [markdown]
# ### How the DTW distance changes with iterations to obtain the dendrogram

# %%
dtw_cluster2.plot_hac_iteration()
plt.show()

# %%
dtw_cluster2.plot_optimum_cluster(legend_outside=False)
# plt.show()
plt.savefig("Figures/optimum_clusters.pdf", bbox_inches='tight')

# %%
def compute_linkage(model):
    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack([model.children_, model.distances_,
                                      counts]).astype(float)
    return linkage_matrix

def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    linkage_matrix = compute_linkage(model)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

# %%
#‘ward’ minimizes the variance of the clusters being merged
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None, affinity='euclidean',linkage='ward')

model = model.fit(X)

plt.figure(figsize=(20, 8))
# plot the top three levels of the dendrogram
plot_dendrogram(model, p=5, color_threshold=5)
plt.xticks(fontsize=26)
plt.yticks(fontsize=26)
plt.axhline(y=5, c='k')


plt.xlabel("Signal Indexes")
plt.savefig('Figures/example_euclidean_cluster.pdf',bbox_inches='tight')
plt.close()

# %%
import ipyplot

# %%
fig, ax = plot_signals(X,figsize=(10,12))
plt.show()

# %%
ipyplot.plot_images(['Figures/example_dtw_cluster.pdf','Figures/example_euclidean_cluster.pdf'], ['DTW','Euclidean'], img_width=450)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-g7Ggx4Av9DAcGttDYTVXRL {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-g7Ggx4Av9DAcGttDYTVXRL {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-g7Ggx4Av9DAcGttDYTVXRL {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-g7Ggx4Av9DAcGttDYTVXRL:checked ~ #ipyplot-html-viewer-textarea-g7Ggx4Av9DAcGttDYTVXRL {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-g7Ggx4Av9DAcGttDYTVXRL:checked + #ipyplot-html-viewer-label-g7Ggx4Av9DAcGttDYTVXRL:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-g7Ggx4Av9DAcGttDYTVXRL">
#         <label id="ipyplot-html-viewer-label-g7Ggx4Av9DAcGttDYTVXRL" for="ipyplot-html-viewer-toggle-g7Ggx4Av9DAcGttDYTVXRL">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-g7Ggx4Av9DAcGttDYTVXRL" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-UnqPyve3sx6dPoA7b7xBxm {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-UnqPyve3sx6dPoA7b7xBxm {
#             width: 450px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm {
#             width: 450px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm img {
#             width: 450px;
#         }
#
#         div.ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-UnqPyve3sx6dPoA7b7xBxm">
#     <div class="ipyplot-placeholder-div-UnqPyve3sx6dPoA7b7xBxm">
#         <div id="ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm-RL4pXpCerwpQcY6FNy22Sy" class="ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">DTW</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/example_dtw_cluster.pdf</h4><img src="Figures/example_dtw_cluster.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm-RL4pXpCerwpQcY6FNy22Sy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-UnqPyve3sx6dPoA7b7xBxm">
#         <div id="ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm-Zd8q7KmvQuHUB2CpJeiyiW" class="ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Euclidean</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/example_euclidean_cluster.pdf</h4><img src="Figures/example_euclidean_cluster.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm-Zd8q7KmvQuHUB2CpJeiyiW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-UnqPyve3sx6dPoA7b7xBxm {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-UnqPyve3sx6dPoA7b7xBxm {
#             width: 450px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm {
#             width: 450px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm img {
#             width: 450px;
#         }
#
#         div.ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-UnqPyve3sx6dPoA7b7xBxm">
#     <div class="ipyplot-placeholder-div-UnqPyve3sx6dPoA7b7xBxm">
#         <div id="ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm-RL4pXpCerwpQcY6FNy22Sy" class="ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">DTW</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/example_dtw_cluster.pdf</h4><img src="Figures/example_dtw_cluster.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm-RL4pXpCerwpQcY6FNy22Sy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-UnqPyve3sx6dPoA7b7xBxm">
#         <div id="ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm-Zd8q7KmvQuHUB2CpJeiyiW" class="ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Euclidean</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/example_euclidean_cluster.pdf</h4><img src="Figures/example_euclidean_cluster.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-UnqPyve3sx6dPoA7b7xBxm-Zd8q7KmvQuHUB2CpJeiyiW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# Both Euclidean and DTW based clustering results are similar. However, we can see some obvious differences. Let us list some of the similarity and differences for the above example.
# 1. Both the results found 5 significant clusters.
# 1. Both Euclidean and DTW based HAC found that the random function based time series (12, 13, 14) are most dissimilar
# 1. The two closest clusters with DTW is sawtooth (6,7,8) and sine func(0,1,2). While that with the Euclidean, it is abs_cosine (6,7,8) and sawtooth fn (3,4,5)
#
# The two results are similar because the signals considered for this example are stationary in nature.

# %%
max_d = 5
Z1= compute_linkage(model)
clusters = fcluster(Z1, max_d, criterion='distance')

plt.figure(figsize=(10, 8))
plt.scatter(lons, lats, c=clusters, cmap='prism', s=120)  # plot points with cluster dependent colors
plt.show()
