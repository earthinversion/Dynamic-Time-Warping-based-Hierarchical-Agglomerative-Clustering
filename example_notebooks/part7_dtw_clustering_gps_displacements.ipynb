# %%
from dtwhaclustering.dtw_analysis import dtw_signal_pairs, dtw_clustering
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
from dtaidistance import dtw
import pandas as pd
import os
# %matplotlib inline 

# default matplotlib parameters
import matplotlib
font = {'family': 'Times',
        'weight': 'bold',
        'size': 22}

matplotlib.rc('font', **font)
plt.rcParams["figure.figsize"] = (12, 6)
plt.style.use('ggplot')

# %%
#load pickle data
dataloc = "pickleFiles"

final_dU=pd.read_pickle(os.path.join(dataloc,"dU_wo_seasn.pickle"))
final_dN=pd.read_pickle(os.path.join(dataloc,"dN_wo_seasn.pickle"))
final_dE=pd.read_pickle(os.path.join(dataloc,"dE_wo_seasn.pickle"))

# %%
final_dU.head()
# Out:
#                DAWU_U    GS36_U    CTOU_U     HSIN_U     GS31_U    SSUN_U  \
# Time
# 2007-01-01   3.908294 -0.081488 -3.049840  -4.673059  10.533776 -1.476313
# 2007-01-02  10.500799  7.948431  1.318779  -0.743764   9.331000  3.753709
# 2007-01-03   4.008854  6.446352  4.105762  12.184217   9.198563  7.073537
# 2007-01-04  -0.031345 -0.846752  0.427601  -3.944638   6.705640 -2.433624
# 2007-01-05  -3.235729  2.166184 -3.995197  -6.788471   6.111140 -2.830265
#
#               SFON_U     GS23_U     VR03_U     SLNP_U  ...     DOSH_U  \
# Time                                                   ...
# 2007-01-01  8.673984   4.530060  13.409948  -8.877830  ... -19.377178
# 2007-01-02  6.669562   4.629491  22.623746   3.637930  ...  -8.896452
# 2007-01-03  6.987663  13.166624  12.013241  -4.880878  ... -22.097870
# 2007-01-04  6.980915   5.301272  14.671148 -12.261464  ... -18.980924
# 2007-01-05 -0.087687   3.937724  14.986668  -6.464705  ... -17.883469
#
#                W029_U    NSHE_U      HUWE_U     SHJU_U     DNAN_U     PKGM_U  \
# Time
# 2007-01-01  -3.788125  1.743015  130.023461   8.220618  66.794490 -30.720817
# 2007-01-02  -6.097189  8.503721  137.846113  13.530092  70.849086 -24.866085
# 2007-01-03   9.628858  2.767164  138.107636  16.818000  72.697599 -19.829117
# 2007-01-04 -11.738634 -0.707047  129.183137   2.833268  66.621516 -31.362671
# 2007-01-05  -8.798023 -1.576212  128.433947  -2.769286  68.346757 -28.545909
#
#                SLIN_U     MESN_U     WULU_U
# Time
# 2007-01-01  -3.034473  -3.599844 -57.474679
# 2007-01-02 -12.179227 -14.733458 -47.341336
# 2007-01-03 -21.627860 -11.893865 -51.522350
# 2007-01-04 -29.660110 -19.988452 -59.711777
# 2007-01-05 -29.302730 -39.140370 -84.028366
#
# [5 rows x 115 columns]

# %%
stn_info_df = pd.read_csv('helper_files/selected_stations_info.txt')
lons = stn_info_df['lon'].values
lats = stn_info_df['lat'].values

# %% [markdown]
# ### Subset of the vertical component data for plotting

# %%
time_series_U_ex = final_dU.values.transpose()[:10,:] #10 stations only

## instantiate the class
dtw_cluster_vertical_ex = dtw_clustering(time_series_U_ex,labels=final_dU.columns.values[:10])

dtw_cluster_vertical_ex.plot_signals(figsize=(10, 20), fontsize=15)
plt.show()

# %% [markdown]
# ### Convert the whole dataframe to numpy array

# %%
time_series_U = final_dU.values.transpose()
time_series_N = final_dN.values.transpose()
time_series_E = final_dE.values.transpose()


time_series_U.shape
# Out:
# (115, 4017)

# %% [markdown]
# ### Perform DTW clustering on all data set

# %%
## instantiate the class
labels = [stnU.split("_")[0] for stnU in final_dU.columns.values] #remove the prefix _U
dtw_cluster_vertical = dtw_clustering(time_series_U,labels=labels, longitudes=lons, latitudes=lats)

# %%
# instantiate the class, and saves the output as ps & pdf
dtw_cluster_vertical.plot_dendrogram(xtickfontsize=8, xlabel="Vertical Stations", ylabel="DTW Distance", figname="Figures/vertical_dtw_cluster_taiwan.png",leaf_rotation=90)
# Out:
# The compiled dtaidistance C-OMP library is not available.
# Use Python's multiprocessing library for parellelization (use_mp=True).
# See the documentation for alternative installation options.
# The compiled dtaidistance C-OMP library is not available.
# Using the Python multiprocessing library instead (use_mp=True).
# See the documentation for alternative installation options.
#
#  99%|█████████▉| 114/115 [00:00<00:00, 8803.78it/s]

# %%
dtw_cluster_north = dtw_clustering(time_series_N,labels=labels, longitudes=lons, latitudes=lats)
dtw_cluster_north.plot_dendrogram(xtickfontsize=8, xlabel="North Stations", ylabel="DTW Distance", figname="Figures/north_dtw_cluster_taiwan.png",leaf_rotation=90)
# Out:
# The compiled dtaidistance C-OMP library is not available.
# Use Python's multiprocessing library for parellelization (use_mp=True).
# See the documentation for alternative installation options.
# The compiled dtaidistance C-OMP library is not available.
# Using the Python multiprocessing library instead (use_mp=True).
# See the documentation for alternative installation options.
#
#  99%|█████████▉| 114/115 [00:00<00:00, 7695.97it/s]

# %%
dtw_cluster_east = dtw_clustering(time_series_E,labels=labels, longitudes=lons, latitudes=lats)
dtw_cluster_east.plot_dendrogram(xtickfontsize=8, xlabel="East Stations", ylabel="DTW Distance", figname="Figures/east_dtw_cluster_taiwan.png",leaf_rotation=90)
# Out:
# The compiled dtaidistance C-OMP library is not available.
# Use Python's multiprocessing library for parellelization (use_mp=True).
# See the documentation for alternative installation options.
# The compiled dtaidistance C-OMP library is not available.
# Using the Python multiprocessing library instead (use_mp=True).
# See the documentation for alternative installation options.
#
#  99%|█████████▉| 114/115 [00:00<00:00, 8129.46it/s]

# %%
import ipyplot
images = []
for comp in ['vertical',"north","east"]:
    clusterFile=f'Figures/{comp}_dtw_cluster_taiwan.pdf'
    images.append(clusterFile)
ipyplot.plot_images(images, ['Vertical','North', 'East'], img_width=800)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-KVHb5Qdeqr7DDDLYSNWMVS {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-KVHb5Qdeqr7DDDLYSNWMVS {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-KVHb5Qdeqr7DDDLYSNWMVS {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-KVHb5Qdeqr7DDDLYSNWMVS:checked ~ #ipyplot-html-viewer-textarea-KVHb5Qdeqr7DDDLYSNWMVS {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-KVHb5Qdeqr7DDDLYSNWMVS:checked + #ipyplot-html-viewer-label-KVHb5Qdeqr7DDDLYSNWMVS:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-KVHb5Qdeqr7DDDLYSNWMVS">
#         <label id="ipyplot-html-viewer-label-KVHb5Qdeqr7DDDLYSNWMVS" for="ipyplot-html-viewer-toggle-KVHb5Qdeqr7DDDLYSNWMVS">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-KVHb5Qdeqr7DDDLYSNWMVS" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-a9FNu5vdAfBiDM8hr82FR5 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-a9FNu5vdAfBiDM8hr82FR5 {
#             width: 800px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5 {
#             width: 800px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5 img {
#             width: 800px;
#         }
#
#         div.ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-a9FNu5vdAfBiDM8hr82FR5">
#     <div class="ipyplot-placeholder-div-a9FNu5vdAfBiDM8hr82FR5">
#         <div id="ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5-S7TK5MUViwigbEAjZ3hLfP" class="ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/vertical_dtw_cluster_taiwan.pdf</h4><img src="Figures/vertical_dtw_cluster_taiwan.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5-S7TK5MUViwigbEAjZ3hLfP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-a9FNu5vdAfBiDM8hr82FR5">
#         <div id="ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5-h2aZaVgvxNMCyoQJqriWeu" class="ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">North</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/north_dtw_cluster_taiwan.pdf</h4><img src="Figures/north_dtw_cluster_taiwan.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5-h2aZaVgvxNMCyoQJqriWeu">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-a9FNu5vdAfBiDM8hr82FR5">
#         <div id="ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5-ntC5xzuF9kqkEqA3ncT8DU" class="ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">East</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/east_dtw_cluster_taiwan.pdf</h4><img src="Figures/east_dtw_cluster_taiwan.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5-ntC5xzuF9kqkEqA3ncT8DU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-a9FNu5vdAfBiDM8hr82FR5 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-a9FNu5vdAfBiDM8hr82FR5 {
#             width: 800px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5 {
#             width: 800px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5 img {
#             width: 800px;
#         }
#
#         div.ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-a9FNu5vdAfBiDM8hr82FR5">
#     <div class="ipyplot-placeholder-div-a9FNu5vdAfBiDM8hr82FR5">
#         <div id="ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5-S7TK5MUViwigbEAjZ3hLfP" class="ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/vertical_dtw_cluster_taiwan.pdf</h4><img src="Figures/vertical_dtw_cluster_taiwan.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5-S7TK5MUViwigbEAjZ3hLfP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-a9FNu5vdAfBiDM8hr82FR5">
#         <div id="ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5-h2aZaVgvxNMCyoQJqriWeu" class="ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">North</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/north_dtw_cluster_taiwan.pdf</h4><img src="Figures/north_dtw_cluster_taiwan.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5-h2aZaVgvxNMCyoQJqriWeu">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-a9FNu5vdAfBiDM8hr82FR5">
#         <div id="ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5-ntC5xzuF9kqkEqA3ncT8DU" class="ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">East</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/east_dtw_cluster_taiwan.pdf</h4><img src="Figures/east_dtw_cluster_taiwan.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-a9FNu5vdAfBiDM8hr82FR5-ntC5xzuF9kqkEqA3ncT8DU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
dtw_cluster_vertical.plot_hac_iteration(figname="Figures/vertical_iteration_gps_taiwan.png")
# Out:
# (None, None)

# %%
ipyplot.plot_images(["Figures/vertical_iteration_gps_taiwan.png"], ['Vertical'], img_width=800)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-f4dLgMn6mmVwqpHwpekyH9 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-f4dLgMn6mmVwqpHwpekyH9 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-f4dLgMn6mmVwqpHwpekyH9 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-f4dLgMn6mmVwqpHwpekyH9:checked ~ #ipyplot-html-viewer-textarea-f4dLgMn6mmVwqpHwpekyH9 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-f4dLgMn6mmVwqpHwpekyH9:checked + #ipyplot-html-viewer-label-f4dLgMn6mmVwqpHwpekyH9:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-f4dLgMn6mmVwqpHwpekyH9">
#         <label id="ipyplot-html-viewer-label-f4dLgMn6mmVwqpHwpekyH9" for="ipyplot-html-viewer-toggle-f4dLgMn6mmVwqpHwpekyH9">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-f4dLgMn6mmVwqpHwpekyH9" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-biZYMj2eoeCZJU2LqzJGGY {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-biZYMj2eoeCZJU2LqzJGGY {
#             width: 800px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY {
#             width: 800px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY img {
#             width: 800px;
#         }
#
#         div.ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-biZYMj2eoeCZJU2LqzJGGY">
#     <div class="ipyplot-placeholder-div-biZYMj2eoeCZJU2LqzJGGY">
#         <div id="ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY-bpaGnPp6KrJx3ATdozVbT5" class="ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/vertical_iteration_gps_taiwan.png</h4><img src="Figures/vertical_iteration_gps_taiwan.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY-bpaGnPp6KrJx3ATdozVbT5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-biZYMj2eoeCZJU2LqzJGGY {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-biZYMj2eoeCZJU2LqzJGGY {
#             width: 800px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY {
#             width: 800px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY img {
#             width: 800px;
#         }
#
#         div.ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-biZYMj2eoeCZJU2LqzJGGY">
#     <div class="ipyplot-placeholder-div-biZYMj2eoeCZJU2LqzJGGY">
#         <div id="ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY-bpaGnPp6KrJx3ATdozVbT5" class="ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/vertical_iteration_gps_taiwan.png</h4><img src="Figures/vertical_iteration_gps_taiwan.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-biZYMj2eoeCZJU2LqzJGGY-bpaGnPp6KrJx3ATdozVbT5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ## Selecting a Distance Cut-Off or Determining the Number of Clusters

# %%
opt_cluster, opt_distance = dtw_cluster_vertical.optimum_cluster_elbow()
opt_cluster, opt_distance
# Out:
# (5, 1350.923006751062)

# %%
dtw_cluster_vertical.plot_cluster_xymap(dtw_distance=2000, figname=None, xlabel='lons', ylabel='lats', scale=4)
plt.show()

# %%
dtw_cluster_vertical.plot_optimum_cluster(xlim=[0,20])
plt.show()

# %%
dtw_cluster_north.plot_optimum_cluster(xlim=[0,20])
plt.show()

# %%
dtw_cluster_east.plot_optimum_cluster(xlim=[0,20])
plt.show()

# %% [markdown]
# ## Plotting Cluster result on a Map

# %%
dtw_cluster_vertical.plot_cluster_geomap(dtw_distance=2000, figname="Figures/vertical_dtw_cluster_geomap.pdf", 
                                         plot_topo=True,
                                         markerstyle='i0.3c',
                                        cmap_topo='geo')
dtw_cluster_north.plot_cluster_geomap(dtw_distance=1500, figname="Figures/north_dtw_cluster_geomap.pdf", 
                                         plot_topo=True,
                                         markerstyle='i0.3c',
                                        cmap_topo='geo')
dtw_cluster_east.plot_cluster_geomap(dtw_distance=4000, figname="Figures/east_dtw_cluster_geomap.pdf", 
                                         plot_topo=True,
                                         markerstyle='i0.3c',
                                        cmap_topo='geo')

# %%
ipyplot.plot_images(['Figures/vertical_dtw_cluster_geomap.pdf',"Figures/north_dtw_cluster_geomap.pdf","Figures/east_dtw_cluster_geomap.pdf"], ['Vertical Cluster','North Cluster','East Cluster'], img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ZtjDqp2efZKhtbezuBNZ4Z {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ZtjDqp2efZKhtbezuBNZ4Z {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ZtjDqp2efZKhtbezuBNZ4Z {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ZtjDqp2efZKhtbezuBNZ4Z:checked ~ #ipyplot-html-viewer-textarea-ZtjDqp2efZKhtbezuBNZ4Z {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ZtjDqp2efZKhtbezuBNZ4Z:checked + #ipyplot-html-viewer-label-ZtjDqp2efZKhtbezuBNZ4Z:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-ZtjDqp2efZKhtbezuBNZ4Z">
#         <label id="ipyplot-html-viewer-label-ZtjDqp2efZKhtbezuBNZ4Z" for="ipyplot-html-viewer-toggle-ZtjDqp2efZKhtbezuBNZ4Z">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-ZtjDqp2efZKhtbezuBNZ4Z" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-H5kGXSykoHNuAGLAQHSkG5 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-H5kGXSykoHNuAGLAQHSkG5 {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5 {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5 img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-H5kGXSykoHNuAGLAQHSkG5">
#     <div class="ipyplot-placeholder-div-H5kGXSykoHNuAGLAQHSkG5">
#         <div id="ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5-Y7uSmGEr4HkgnURVngJtzR" class="ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical Cluster</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/vertical_dtw_cluster_geomap.pdf</h4><img src="Figures/vertical_dtw_cluster_geomap.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5-Y7uSmGEr4HkgnURVngJtzR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-H5kGXSykoHNuAGLAQHSkG5">
#         <div id="ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5-BYmKSXNmziWSGRBXoDQDYj" class="ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">North Cluster</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/north_dtw_cluster_geomap.pdf</h4><img src="Figures/north_dtw_cluster_geomap.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5-BYmKSXNmziWSGRBXoDQDYj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-H5kGXSykoHNuAGLAQHSkG5">
#         <div id="ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5-SwLpThZEotnpqoe66Z9NtT" class="ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">East Cluster</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/east_dtw_cluster_geomap.pdf</h4><img src="Figures/east_dtw_cluster_geomap.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5-SwLpThZEotnpqoe66Z9NtT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-H5kGXSykoHNuAGLAQHSkG5 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-H5kGXSykoHNuAGLAQHSkG5 {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5 {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5 img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-H5kGXSykoHNuAGLAQHSkG5">
#     <div class="ipyplot-placeholder-div-H5kGXSykoHNuAGLAQHSkG5">
#         <div id="ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5-Y7uSmGEr4HkgnURVngJtzR" class="ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical Cluster</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/vertical_dtw_cluster_geomap.pdf</h4><img src="Figures/vertical_dtw_cluster_geomap.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5-Y7uSmGEr4HkgnURVngJtzR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-H5kGXSykoHNuAGLAQHSkG5">
#         <div id="ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5-BYmKSXNmziWSGRBXoDQDYj" class="ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">North Cluster</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/north_dtw_cluster_geomap.pdf</h4><img src="Figures/north_dtw_cluster_geomap.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5-BYmKSXNmziWSGRBXoDQDYj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-H5kGXSykoHNuAGLAQHSkG5">
#         <div id="ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5-SwLpThZEotnpqoe66Z9NtT" class="ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">East Cluster</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/east_dtw_cluster_geomap.pdf</h4><img src="Figures/east_dtw_cluster_geomap.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-H5kGXSykoHNuAGLAQHSkG5-SwLpThZEotnpqoe66Z9NtT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
opt_cluster, opt_distance
# Out:
# (5, 1350.923006751062)

# %%
diff = 0
opt_cluster, opt_distance = dtw_cluster_vertical.optimum_cluster_elbow()
print(opt_cluster, opt_distance)
dtw_cluster_vertical.plot_cluster_geomap_interpolated(dtw_distance=opt_distance-diff,
                                         lonrange=(120., 122.),
                                         latrange=(21.8, 25.6),
                                         gridstep=0.01,
                                         figname="Figures/vertical_dtw_cluster_geomap_intrp.pdf",
                                         markerstyle='i0.3c',
                                         dpi=720,
                                         doffset=1)

opt_cluster, opt_distance = dtw_cluster_north.optimum_cluster_elbow()
print(opt_cluster, opt_distance)

dtw_cluster_north.plot_cluster_geomap_interpolated(dtw_distance=opt_distance-diff,
                                         lonrange=(120., 122.),
                                         latrange=(21.8, 25.6),
                                         gridstep=0.01,
                                         figname="Figures/north_dtw_cluster_geomap_intrp.pdf",
                                         markerstyle='i0.3c',
                                         dpi=720,
                                         doffset=1)

opt_cluster, opt_distance = dtw_cluster_east.optimum_cluster_elbow()
print(opt_cluster, opt_distance)
dtw_cluster_east.plot_cluster_geomap_interpolated(dtw_distance=opt_distance-diff,
                                         lonrange=(120., 122.),
                                         latrange=(21.8, 25.6),
                                         gridstep=0.01,
                                         figname="Figures/east_dtw_cluster_geomap_intrp.pdf",
                                         markerstyle='i0.3c',
                                         dpi=720,
                                         doffset=1)
# Out:
# 5 1350.923006751062
# 5 1737.6234862804804
# 3 4434.887798982461

# %%
ipyplot.plot_images(['Figures/vertical_dtw_cluster_geomap_intrp.pdf',"Figures/north_dtw_cluster_geomap_intrp.pdf","Figures/east_dtw_cluster_geomap_intrp.pdf"], ['Vertical Cluster','North Cluster','East Cluster'], img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-jwMX53MS4qdFLD4Rfz8cRa {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jwMX53MS4qdFLD4Rfz8cRa {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jwMX53MS4qdFLD4Rfz8cRa {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jwMX53MS4qdFLD4Rfz8cRa:checked ~ #ipyplot-html-viewer-textarea-jwMX53MS4qdFLD4Rfz8cRa {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jwMX53MS4qdFLD4Rfz8cRa:checked + #ipyplot-html-viewer-label-jwMX53MS4qdFLD4Rfz8cRa:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-jwMX53MS4qdFLD4Rfz8cRa">
#         <label id="ipyplot-html-viewer-label-jwMX53MS4qdFLD4Rfz8cRa" for="ipyplot-html-viewer-toggle-jwMX53MS4qdFLD4Rfz8cRa">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-jwMX53MS4qdFLD4Rfz8cRa" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-iqjR24U9ECFMr3g2HWPovC {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-iqjR24U9ECFMr3g2HWPovC {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-iqjR24U9ECFMr3g2HWPovC">
#     <div class="ipyplot-placeholder-div-iqjR24U9ECFMr3g2HWPovC">
#         <div id="ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC-MYEB9queEowy7L5thNuFoy" class="ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical Cluster</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/vertical_dtw_cluster_geomap_intrp.pdf</h4><img src="Figures/vertical_dtw_cluster_geomap_intrp.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC-MYEB9queEowy7L5thNuFoy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iqjR24U9ECFMr3g2HWPovC">
#         <div id="ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC-anek3nijAc7Udu8AYbTu6U" class="ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC">
#             <h4 style="font-size: 12px; word-wrap: break-word;">North Cluster</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/north_dtw_cluster_geomap_intrp.pdf</h4><img src="Figures/north_dtw_cluster_geomap_intrp.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC-anek3nijAc7Udu8AYbTu6U">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iqjR24U9ECFMr3g2HWPovC">
#         <div id="ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC-GxQnQxS9eMmsxi2RGicqJR" class="ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC">
#             <h4 style="font-size: 12px; word-wrap: break-word;">East Cluster</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/east_dtw_cluster_geomap_intrp.pdf</h4><img src="Figures/east_dtw_cluster_geomap_intrp.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC-GxQnQxS9eMmsxi2RGicqJR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-iqjR24U9ECFMr3g2HWPovC {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-iqjR24U9ECFMr3g2HWPovC {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-iqjR24U9ECFMr3g2HWPovC">
#     <div class="ipyplot-placeholder-div-iqjR24U9ECFMr3g2HWPovC">
#         <div id="ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC-MYEB9queEowy7L5thNuFoy" class="ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical Cluster</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/vertical_dtw_cluster_geomap_intrp.pdf</h4><img src="Figures/vertical_dtw_cluster_geomap_intrp.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC-MYEB9queEowy7L5thNuFoy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iqjR24U9ECFMr3g2HWPovC">
#         <div id="ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC-anek3nijAc7Udu8AYbTu6U" class="ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC">
#             <h4 style="font-size: 12px; word-wrap: break-word;">North Cluster</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/north_dtw_cluster_geomap_intrp.pdf</h4><img src="Figures/north_dtw_cluster_geomap_intrp.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC-anek3nijAc7Udu8AYbTu6U">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iqjR24U9ECFMr3g2HWPovC">
#         <div id="ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC-GxQnQxS9eMmsxi2RGicqJR" class="ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC">
#             <h4 style="font-size: 12px; word-wrap: break-word;">East Cluster</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Figures/east_dtw_cluster_geomap_intrp.pdf</h4><img src="Figures/east_dtw_cluster_geomap_intrp.pdf"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iqjR24U9ECFMr3g2HWPovC-GxQnQxS9eMmsxi2RGicqJR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
