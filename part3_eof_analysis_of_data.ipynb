# %% [markdown]
# ## PART 3: EOF analysis of the data without seasonality, trend, jumps

# %% [markdown]
# This script aims to:
# - Least squares model to remove the tidal and seasonal signals as well as co-seismic jumps
# - Earthquakes selected are obtained from wilber 3 web interface
# - Co-seismic jumps from selected earthquakes (>5.1 Mw)
#
# ### Required:
# - python
# - pandas
# - jupyter
# - notebook
# - matplotlib
# - pygmt
# - MATLAB
#
# ```
# pip install ipyplot
# pip install pygmt
# ```
#
# __Author: Utpal Kumar @Institute of Earth Sciences, Academia Sinica__

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import os
import ipyplot

# %% [markdown]
# Estimate the EOF modes, first mode prefereably CME if the trend, coseism and the seasonality are removed

# %%
# %%bash
# ## perform EOF analysis to obtain the CME
# matlab="/Applications/MATLAB_R2020b.app/bin/matlab"
# ${matlab} -nodisplay -nodesktop -r "try; CMEestimation; catch; end; quit";
# Out:
#                                                                               < M A T L A B (R) >
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#                                                                 R2020b Update 5 (9.9.0.1592791) 64-bit (maci64)
#                                                                                 February 4, 2021
#
# Warning: Name is nonexistent or not a directory: /private/var/folders/fl/pcgkhm492f9fj6cx4xybs09h0000gp/T/Editor_onfow]
#
# To get started, type doc.
# For product information, visit www.mathworks.com.
# 2021-06-06 18:16:00.367 MATLAB[17435:128827] CoreText note: Client requested name ".SFNS-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2021-06-06 18:16:00.367 MATLAB[17435:128827] CoreText note: Set a breakpoint on CTFontLogSystemFontNameRequest to debug.
# 2021-06-06 18:16:00.370 MATLAB[17435:128827] CoreText note: Client requested name ".SFNS-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2021-06-06 18:16:00.446 MATLAB[17435:128827] CoreText note: Client requested name ".SFNS-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2021-06-06 18:16:00.446 MATLAB[17435:128827] CoreText note: Client requested name ".SFNS-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].

# %%
## Show the resulting images
matlabFigures="MATLAB_output"
images_spatial = []
images_ts = []
for comp in ["U", "N", "E"]:
    images_spatial.append(os.path.join(matlabFigures, f"eof1_CGPS_comp_spatial{comp}.png"))
    images_ts.append(os.path.join(matlabFigures, f"eof1_comp_temp_amp{comp}.png"))


images = images_spatial

labels=["Vertical","North","East"]

ipyplot.plot_images(images, labels, img_width=300)
ipyplot.plot_images(images_ts, labels, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-WHe5YrfgqcEWjSVYzJWfA2 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-WHe5YrfgqcEWjSVYzJWfA2 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-WHe5YrfgqcEWjSVYzJWfA2 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-WHe5YrfgqcEWjSVYzJWfA2:checked ~ #ipyplot-html-viewer-textarea-WHe5YrfgqcEWjSVYzJWfA2 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-WHe5YrfgqcEWjSVYzJWfA2:checked + #ipyplot-html-viewer-label-WHe5YrfgqcEWjSVYzJWfA2:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle
:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-KjyZD4QuzXg4YYwjgWNFjH">
#     <div class="ipyplot-placeholder-div-KjyZD4QuzXg4YYwjgWNFjH">
#         <div id="ipyplot-content-div-KjyZD4QuzXg4YYwjgWNFjH-LsAe5YzbAja2SDfCiZPE5X" class="ipyplot-content-div-KjyZD4QuzXg4YYwjgWNFjH">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_CGPS_comp_spatialU.png</h4><img src="MATLAB_output/eof1_CGPS_comp_spatialU.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KjyZD4QuzXg4YYwjgWNFjH-LsAe5YzbAja2SDfCiZPE5X">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KjyZD4QuzXg4YYwjgWNFjH">
#         <div id="ipyplot-content-div-KjyZD4QuzXg4YYwjgWNFjH-nVhmytoqF9zGgBhHBPrnoR" class="ipyplot-content-div-KjyZD4QuzXg4YYwjgWNFjH">
#             <h4 style="font-size: 12px; word-wrap: break-word;">North</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_CGPS_comp_spatialN.png</h4><img src="MATLAB_output/eof1_CGPS_comp_spatialN.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KjyZD4QuzXg4YYwjgWNFjH-nVhmytoqF9zGgBhHBPrnoR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KjyZD4QuzXg4YYwjgWNFjH">
#         <div id="ipyplot-content-div-KjyZD4QuzXg4YYwjgWNFjH-ahXu4PFuVmXshH5FJkdqYZ" class="ipyplot-content-div-KjyZD4QuzXg4YYwjgWNFjH">
#             <h4 style="font-size: 12px; word-wrap: break-word;">East</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_CGPS_comp_spatialE.png</h4><img src="MATLAB_output/eof1_CGPS_comp_spatialE.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KjyZD4QuzXg4YYwjgWNFjH-ahXu4PFuVmXshH5FJkdqYZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#     <style>
#         #ipyplot-html-viewer-toggle-XyTHyMMbPAyJGp7QekTYGc {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-XyTHyMMbPAyJGp7QekTYGc {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-XyTHyMMbPAyJGp7QekTYGc {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-XyTHyMMbPAyJGp7QekTYGc:checked ~ #ipyplot-html-viewer-textarea-XyTHyMMbPAyJGp7QekTYGc {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-XyTHyMMbPAyJGp7QekTYGc:checked + #ipyplot-html-viewer-label-XyTHyMMbPAyJGp7QekTYGc:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-XyTHyMMbPAyJGp7QekTYGc">
#         <label id="ipyplot-html-viewer-label-XyTHyMMbPAyJGp7QekTYGc" for="ipyplot-html-viewer-toggle-XyTHyMMbPAyJGp7QekTYGc">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-XyTHyMMbPAyJGp7QekTYGc" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-k5JiSfCCsYkViSrVPmZDqM {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-k5JiSfCCsYkViSrVPmZDqM {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-k5JiSfCCsYkViSrVPmZDqM">
#     <div class="ipyplot-placeholder-div-k5JiSfCCsYkViSrVPmZDqM">
#         <div id="ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM-HEPo5BGwmkttp34cR7CYqx" class="ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_comp_temp_ampU.png</h4><img src="MATLAB_output/eof1_comp_temp_ampU.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM-HEPo5BGwmkttp34cR7CYqx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-k5JiSfCCsYkViSrVPmZDqM">
#         <div id="ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM-YwG5Z867odBX3dNh9LmFAU" class="ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">North</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_comp_temp_ampN.png</h4><img src="MATLAB_output/eof1_comp_temp_ampN.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM-YwG5Z867odBX3dNh9LmFAU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-k5JiSfCCsYkViSrVPmZDqM">
#         <div id="ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM-PG5nRPvArGjUCzTM8zaEhL" class="ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">East</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_comp_temp_ampE.png</h4><img src="MATLAB_output/eof1_comp_temp_ampE.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM-PG5nRPvArGjUCzTM8zaEhL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-k5JiSfCCsYkViSrVPmZDqM {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-k5JiSfCCsYkViSrVPmZDqM {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-k5JiSfCCsYkViSrVPmZDqM">
#     <div class="ipyplot-placeholder-div-k5JiSfCCsYkViSrVPmZDqM">
#         <div id="ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM-HEPo5BGwmkttp34cR7CYqx" class="ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_comp_temp_ampU.png</h4><img src="MATLAB_output/eof1_comp_temp_ampU.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM-HEPo5BGwmkttp34cR7CYqx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-k5JiSfCCsYkViSrVPmZDqM">
#         <div id="ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM-YwG5Z867odBX3dNh9LmFAU" class="ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">North</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_comp_temp_ampN.png</h4><img src="MATLAB_output/eof1_comp_temp_ampN.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM-YwG5Z867odBX3dNh9LmFAU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-k5JiSfCCsYkViSrVPmZDqM">
#         <div id="ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM-PG5nRPvArGjUCzTM8zaEhL" class="ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">East</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_comp_temp_ampE.png</h4><img src="MATLAB_output/eof1_comp_temp_ampE.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-k5JiSfCCsYkViSrVPmZDqM-PG5nRPvArGjUCzTM8zaEhL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# Notice that the spatial pattern is coherent for the region. This is characteristic feature of CME.
