# %% [markdown]
# ## PART 3: EOF analysis of the data without seasonality, trend, jumps

# %% [markdown]
# This script aims to:
# - Least squares model to remove the tidal and seasonal signals as well as co-seismic jumps
# - Earthquakes selected are obtained from wilber 3 web interface
# - Co-seismic jumps from selected earthquakes (>5.1 Mw)
#
# ### Required:
# - python
# - pandas
# - jupyter
# - notebook
# - matplotlib
# - pygmt
# - MATLAB
#
# ```
# pip install ipyplot
# pip install pygmt
# ```
#
# __Author: Utpal Kumar @Institute of Earth Sciences, Academia Sinica__

# %% [markdown]
# ## Import libraries

# %%
from dtwclustering import plot_stations
from IPython.display import Image, display
import pandas as pd
import os
import ipyplot

# %%
## read the station info file
stnloc = pd.read_csv('helper_files/selected_stations_info.txt')
print(f"Total stations: {stnloc.shape[0]}")
stnloc.head()
# Out:
# Total stations: 115
#     stn        lon       lat
# 0  DAWU  120.89004  22.34059
# 1  GS36  120.62533  24.36204
# 2  CTOU  120.27784  22.75468
# 3  HSIN  121.01425  24.82775
# 4  GS31  120.27576  23.01890

# %%
outloc="Maps"
plot_stations.plot_station_map(station_data = 'helper_files/selected_stations_info.txt', outloc=outloc)
ipyplot.plot_images([f'{outloc}/station_map.png'], ['Station Map'], img_width=500)
# Out:
#     stn        lon       lat
# 0  DAWU  120.89004  22.34059
# 1  GS36  120.62533  24.36204
# 2  CTOU  120.27784  22.75468
# 3  HSIN  121.01425  24.82775
# 4  GS31  120.27576  23.01890
# Output figure saved at Maps/station_map.png
#     <style>
#         #ipyplot-html-viewer-toggle-mczZ6uA4F5uvtaNdiPpVzm {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-mczZ6uA4F5uvtaNdiPpVzm {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-mczZ6uA4F5uvtaNdiPpVzm {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-mczZ6uA4F5uvtaNdiPpVzm:checked ~ #ipyplot-html-viewer-textarea-mczZ6uA4F5uvtaNdiPpVzm {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-mczZ6uA4F5uvtaNdiPpVzm:checked + #ipyplot-html-viewer-label-mczZ6uA4F5uvtaNdiPpVzm:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-mczZ6uA4F5uvtaNdiPpVzm">
#         <label id="ipyplot-html-viewer-label-mczZ6uA4F5uvtaNdiPpVzm" for="ipyplot-html-viewer-toggle-mczZ6uA4F5uvtaNdiPpVzm">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-mczZ6uA4F5uvtaNdiPpVzm" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-hc7JzPk8nChw2Lp5UvNeRR {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-hc7JzPk8nChw2Lp5UvNeRR {
#             width: 600px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR {
#             width: 600px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR img {
#             width: 600px;
#         }
#
#         div.ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-hc7JzPk8nChw2Lp5UvNeRR">
#     <div class="ipyplot-placeholder-div-hc7JzPk8nChw2Lp5UvNeRR">
#         <div id="ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR-oMDY94y9QY8waP6tMGFSq4" class="ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Station Map</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Maps/station_map.png</h4><img src="Maps/station_map.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR-oMDY94y9QY8waP6tMGFSq4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-hc7JzPk8nChw2Lp5UvNeRR {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-hc7JzPk8nChw2Lp5UvNeRR {
#             width: 600px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR {
#             width: 600px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR img {
#             width: 600px;
#         }
#
#         div.ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-hc7JzPk8nChw2Lp5UvNeRR">
#     <div class="ipyplot-placeholder-div-hc7JzPk8nChw2Lp5UvNeRR">
#         <div id="ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR-oMDY94y9QY8waP6tMGFSq4" class="ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Station Map</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">Maps/station_map.png</h4><img src="Maps/station_map.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hc7JzPk8nChw2Lp5UvNeRR-oMDY94y9QY8waP6tMGFSq4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# <!-- display(Image(filename=os.path.join(outloc,'station_map.png')) )   -->
# <!-- <img src="Maps/station_map.png" alt="Station Map" width="500"/> -->

# %% [markdown]
# Estimate the EOF modes, first mode prefereably CME if the trend, coseism and the seasonality are removed

# %%
# %%bash
# ## perform EOF analysis to obtain the CME
# matlab="/Applications/MATLAB_R2020b.app/bin/matlab"
# ${matlab} -nodisplay -nodesktop -r "try; CMEestimation; catch; end; quit";
# Out:
#                                                                               < M A T L A B (R) >
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#                                                                 R2020b Update 5 (9.9.0.1592791) 64-bit (maci64)
#                                                                                 February 4, 2021
#
# Warning: Name is nonexistent or not a directory: /private/var/folders/fl/pcgkhm492f9fj6cx4xybs09h0000gp/T/Editor_onfow]
#
# To get started, type doc.
# For product information, visit www.mathworks.com.
# 2021-06-06 12:41:25.194 MATLAB[19544:1233817] CoreText note: Client requested name ".SFNS-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2021-06-06 12:41:25.194 MATLAB[19544:1233817] CoreText note: Set a breakpoint on CTFontLogSystemFontNameRequest to debug.
# 2021-06-06 12:41:25.197 MATLAB[19544:1233817] CoreText note: Client requested name ".SFNS-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2021-06-06 12:41:25.266 MATLAB[19544:1233817] CoreText note: Client requested name ".SFNS-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2021-06-06 12:41:25.266 MATLAB[19544:1233817] CoreText note: Client requested name ".SFNS-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].

# %%
## Show the resulting images
matlabFigures="MATLAB_output"
images_spatial = []
images_ts = []
for comp in ["U", "N", "E"]:
    images_spatial.append(os.path.join(matlabFigures, f"eof1_CGPS_comp_spatial{comp}.png"))
    images_ts.append(os.path.join(matlabFigures, f"eof1_comp_temp_amp{comp}.png"))


images = images_spatial

labels=["Vertical","North","East"]

ipyplot.plot_images(images, labels, img_width=300)
ipyplot.plot_images(images_ts, labels, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-jZhfQaDLxDiGh5f4Y8ewiq {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jZhfQaDLxDiGh5f4Y8ewiq {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jZhfQaDLxDiGh5f4Y8ewiq {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jZhfQaDLxDiGh5f4Y8ewiq:checked ~ #ipyplot-html-viewer-textarea-jZhfQaDLxDiGh5f4Y8ewiq {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jZhfQaDLxDiGh5f4Y8ewiq:checked + #ipyplot-html-viewer-label-jZhfQaDLxDiGh5f4Y8ewiq:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-jZhfQaDLxDiGh5f4Y8ewiq">
#         <label id="ipyplot-html-viewer-label-jZhfQaDLxDiGh5f4Y8ewiq" for="ipyplot-html-viewer-toggle-jZhfQaDLxDiGh5f4Y8ewiq">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-jZhfQaDLxDiGh5f4Y8ewiq" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-mCZncpmqJaWoN8Br3RubgX {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-mCZncpmqJaWoN8Br3RubgX {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-mCZncpmqJaWoN8Br3RubgX">
#     <div class="ipyplot-placeholder-div-mCZncpmqJaWoN8Br3RubgX">
#         <div id="ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX-FZ7ekqoP7SkTNyJfdg9xVf" class="ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_CGPS_comp_spatialU.png</h4><img src="MATLAB_output/eof1_CGPS_comp_spatialU.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX-FZ7ekqoP7SkTNyJfdg9xVf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mCZncpmqJaWoN8Br3RubgX">
#         <div id="ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX-PmsBGhhjrvYm9mnBBJPYJv" class="ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">North</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_CGPS_comp_spatialN.png</h4><img src="MATLAB_output/eof1_CGPS_comp_spatialN.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX-PmsBGhhjrvYm9mnBBJPYJv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mCZncpmqJaWoN8Br3RubgX">
#         <div id="ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX-TF4KPenHJSNyHuGcTqKXxT" class="ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">East</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_CGPS_comp_spatialE.png</h4><img src="MATLAB_output/eof1_CGPS_comp_spatialE.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX-TF4KPenHJSNyHuGcTqKXxT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-mCZncpmqJaWoN8Br3RubgX {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-mCZncpmqJaWoN8Br3RubgX {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-mCZncpmqJaWoN8Br3RubgX">
#     <div class="ipyplot-placeholder-div-mCZncpmqJaWoN8Br3RubgX">
#         <div id="ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX-FZ7ekqoP7SkTNyJfdg9xVf" class="ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_CGPS_comp_spatialU.png</h4><img src="MATLAB_output/eof1_CGPS_comp_spatialU.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX-FZ7ekqoP7SkTNyJfdg9xVf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mCZncpmqJaWoN8Br3RubgX">
#         <div id="ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX-PmsBGhhjrvYm9mnBBJPYJv" class="ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">North</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_CGPS_comp_spatialN.png</h4><img src="MATLAB_output/eof1_CGPS_comp_spatialN.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX-PmsBGhhjrvYm9mnBBJPYJv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mCZncpmqJaWoN8Br3RubgX">
#         <div id="ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX-TF4KPenHJSNyHuGcTqKXxT" class="ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">East</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_CGPS_comp_spatialE.png</h4><img src="MATLAB_output/eof1_CGPS_comp_spatialE.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mCZncpmqJaWoN8Br3RubgX-TF4KPenHJSNyHuGcTqKXxT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#     <style>
#         #ipyplot-html-viewer-toggle-fWbErdw8PrAoWpN9e9a6Vr {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-fWbErdw8PrAoWpN9e9a6Vr {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-fWbErdw8PrAoWpN9e9a6Vr {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-fWbErdw8PrAoWpN9e9a6Vr:checked ~ #ipyplot-html-viewer-textarea-fWbErdw8PrAoWpN9e9a6Vr {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-fWbErdw8PrAoWpN9e9a6Vr:checked + #ipyplot-html-viewer-label-fWbErdw8PrAoWpN9e9a6Vr:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-fWbErdw8PrAoWpN9e9a6Vr">
#         <label id="ipyplot-html-viewer-label-fWbErdw8PrAoWpN9e9a6Vr" for="ipyplot-html-viewer-toggle-fWbErdw8PrAoWpN9e9a6Vr">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-fWbErdw8PrAoWpN9e9a6Vr" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-HBJuckboniuuAxermbHBKX {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-HBJuckboniuuAxermbHBKX {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-HBJuckboniuuAxermbHBKX {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HBJuckboniuuAxermbHBKX span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-HBJuckboniuuAxermbHBKX span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HBJuckboniuuAxermbHBKX img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-HBJuckboniuuAxermbHBKX span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-HBJuckboniuuAxermbHBKX span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-HBJuckboniuuAxermbHBKX]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-HBJuckboniuuAxermbHBKX]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-HBJuckboniuuAxermbHBKX]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-HBJuckboniuuAxermbHBKX">
#     <div class="ipyplot-placeholder-div-HBJuckboniuuAxermbHBKX">
#         <div id="ipyplot-content-div-HBJuckboniuuAxermbHBKX-K4Rep6mpnR3BBqRUyPWRnT" class="ipyplot-content-div-HBJuckboniuuAxermbHBKX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_comp_temp_ampU.png</h4><img src="MATLAB_output/eof1_comp_temp_ampU.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HBJuckboniuuAxermbHBKX-K4Rep6mpnR3BBqRUyPWRnT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-HBJuckboniuuAxermbHBKX">
#         <div id="ipyplot-content-div-HBJuckboniuuAxermbHBKX-NPq39b2fgBQtwizccdfUj6" class="ipyplot-content-div-HBJuckboniuuAxermbHBKX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">North</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_comp_temp_ampN.png</h4><img src="MATLAB_output/eof1_comp_temp_ampN.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HBJuckboniuuAxermbHBKX-NPq39b2fgBQtwizccdfUj6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-HBJuckboniuuAxermbHBKX">
#         <div id="ipyplot-content-div-HBJuckboniuuAxermbHBKX-8PkMwo7UXE3S556wYdtFZX" class="ipyplot-content-div-HBJuckboniuuAxermbHBKX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">East</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_comp_temp_ampE.png</h4><img src="MATLAB_output/eof1_comp_temp_ampE.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HBJuckboniuuAxermbHBKX-8PkMwo7UXE3S556wYdtFZX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-HBJuckboniuuAxermbHBKX {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-HBJuckboniuuAxermbHBKX {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-HBJuckboniuuAxermbHBKX {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HBJuckboniuuAxermbHBKX span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-HBJuckboniuuAxermbHBKX span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HBJuckboniuuAxermbHBKX img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-HBJuckboniuuAxermbHBKX span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-HBJuckboniuuAxermbHBKX span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-HBJuckboniuuAxermbHBKX]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-HBJuckboniuuAxermbHBKX]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-HBJuckboniuuAxermbHBKX]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-HBJuckboniuuAxermbHBKX">
#     <div class="ipyplot-placeholder-div-HBJuckboniuuAxermbHBKX">
#         <div id="ipyplot-content-div-HBJuckboniuuAxermbHBKX-K4Rep6mpnR3BBqRUyPWRnT" class="ipyplot-content-div-HBJuckboniuuAxermbHBKX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_comp_temp_ampU.png</h4><img src="MATLAB_output/eof1_comp_temp_ampU.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HBJuckboniuuAxermbHBKX-K4Rep6mpnR3BBqRUyPWRnT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-HBJuckboniuuAxermbHBKX">
#         <div id="ipyplot-content-div-HBJuckboniuuAxermbHBKX-NPq39b2fgBQtwizccdfUj6" class="ipyplot-content-div-HBJuckboniuuAxermbHBKX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">North</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_comp_temp_ampN.png</h4><img src="MATLAB_output/eof1_comp_temp_ampN.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HBJuckboniuuAxermbHBKX-NPq39b2fgBQtwizccdfUj6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-HBJuckboniuuAxermbHBKX">
#         <div id="ipyplot-content-div-HBJuckboniuuAxermbHBKX-8PkMwo7UXE3S556wYdtFZX" class="ipyplot-content-div-HBJuckboniuuAxermbHBKX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">East</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/eof1_comp_temp_ampE.png</h4><img src="MATLAB_output/eof1_comp_temp_ampE.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HBJuckboniuuAxermbHBKX-8PkMwo7UXE3S556wYdtFZX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# Notice that the spatial pattern is coherent for the region. This is characteristic feature of CME.

# %% [markdown]
# ## Compute the EOF map of Taiwan on the GPS displacements without seasonality
# - We keep the trend and co-seismic jumps this time

# %%
# %%bash
# ## perform EOF analysis to obtain the EOF map
# matlab="/Applications/MATLAB_R2020b.app/bin/matlab"
# ${matlab} -nodisplay -nodesktop -r "try; EOF_taiwan_stations; catch; end; quit";
# Out:
#                                                                               < M A T L A B (R) >
#                                                                     Copyright 1984-2020 The MathWorks, Inc.
#                                                                 R2020b Update 5 (9.9.0.1592791) 64-bit (maci64)
#                                                                                 February 4, 2021
#
# Warning: Name is nonexistent or not a directory: /private/var/folders/fl/pcgkhm492f9fj6cx4xybs09h0000gp/T/Editor_onfow]
#
# To get started, type doc.
# For product information, visit www.mathworks.com.
# 2021-06-06 12:50:24.285 MATLAB[20891:1262004] CoreText note: Client requested name ".SFNS-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2021-06-06 12:50:24.285 MATLAB[20891:1262004] CoreText note: Set a breakpoint on CTFontLogSystemFontNameRequest to debug.
# 2021-06-06 12:50:24.288 MATLAB[20891:1262004] CoreText note: Client requested name ".SFNS-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2021-06-06 12:50:24.358 MATLAB[20891:1262004] CoreText note: Client requested name ".SFNS-Regular", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2021-06-06 12:50:24.358 MATLAB[20891:1262004] CoreText note: Client requested name ".SFNS-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].

# %%
## Show the resulting images
matlabFigures="MATLAB_output"
images_spatial = []
images_ts = []
for comp in ["U", "N", "E"]:
    images_spatial.append(os.path.join(matlabFigures, f"with_tr_jmp_eof1_CGPS_comp_spatial{comp}.png"))
    images_ts.append(os.path.join(matlabFigures, f"with_tr_jmp_eof1_comp_temp_amp{comp}.png"))


images = images_spatial

labels=["Vertical","North","East"]

ipyplot.plot_images(images, labels, img_width=300)
ipyplot.plot_images(images_ts, labels, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-7Wgr4Y4EPHZSRpRywaw2PX {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-7Wgr4Y4EPHZSRpRywaw2PX {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-7Wgr4Y4EPHZSRpRywaw2PX {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-7Wgr4Y4EPHZSRpRywaw2PX:checked ~ #ipyplot-html-viewer-textarea-7Wgr4Y4EPHZSRpRywaw2PX {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-7Wgr4Y4EPHZSRpRywaw2PX:checked + #ipyplot-html-viewer-label-7Wgr4Y4EPHZSRpRywaw2PX:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-7Wgr4Y4EPHZSRpRywaw2PX">
#         <label id="ipyplot-html-viewer-label-7Wgr4Y4EPHZSRpRywaw2PX" for="ipyplot-html-viewer-toggle-7Wgr4Y4EPHZSRpRywaw2PX">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-7Wgr4Y4EPHZSRpRywaw2PX" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-bZtrsCPNWnbduFFs4Y5Rvm {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-bZtrsCPNWnbduFFs4Y5Rvm {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-bZtrsCPNWnbduFFs4Y5Rvm">
#     <div class="ipyplot-placeholder-div-bZtrsCPNWnbduFFs4Y5Rvm">
#         <div id="ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm-73QpcwxBDLonV3QXDDugD6" class="ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/with_tr_jmp_eof1_CGPS_comp_spatialU.png</h4><img src="MATLAB_output/with_tr_jmp_eof1_CGPS_comp_spatialU.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm-73QpcwxBDLonV3QXDDugD6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bZtrsCPNWnbduFFs4Y5Rvm">
#         <div id="ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm-ZiRnJ9K4tr7xSYtENsvW46" class="ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">North</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/with_tr_jmp_eof1_CGPS_comp_spatialN.png</h4><img src="MATLAB_output/with_tr_jmp_eof1_CGPS_comp_spatialN.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm-ZiRnJ9K4tr7xSYtENsvW46">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bZtrsCPNWnbduFFs4Y5Rvm">
#         <div id="ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm-LV74VFnT5NwNqC4w8qSpb2" class="ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">East</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/with_tr_jmp_eof1_CGPS_comp_spatialE.png</h4><img src="MATLAB_output/with_tr_jmp_eof1_CGPS_comp_spatialE.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm-LV74VFnT5NwNqC4w8qSpb2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-bZtrsCPNWnbduFFs4Y5Rvm {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-bZtrsCPNWnbduFFs4Y5Rvm {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-bZtrsCPNWnbduFFs4Y5Rvm">
#     <div class="ipyplot-placeholder-div-bZtrsCPNWnbduFFs4Y5Rvm">
#         <div id="ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm-73QpcwxBDLonV3QXDDugD6" class="ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/with_tr_jmp_eof1_CGPS_comp_spatialU.png</h4><img src="MATLAB_output/with_tr_jmp_eof1_CGPS_comp_spatialU.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm-73QpcwxBDLonV3QXDDugD6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bZtrsCPNWnbduFFs4Y5Rvm">
#         <div id="ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm-ZiRnJ9K4tr7xSYtENsvW46" class="ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">North</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/with_tr_jmp_eof1_CGPS_comp_spatialN.png</h4><img src="MATLAB_output/with_tr_jmp_eof1_CGPS_comp_spatialN.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm-ZiRnJ9K4tr7xSYtENsvW46">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bZtrsCPNWnbduFFs4Y5Rvm">
#         <div id="ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm-LV74VFnT5NwNqC4w8qSpb2" class="ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">East</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/with_tr_jmp_eof1_CGPS_comp_spatialE.png</h4><img src="MATLAB_output/with_tr_jmp_eof1_CGPS_comp_spatialE.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bZtrsCPNWnbduFFs4Y5Rvm-LV74VFnT5NwNqC4w8qSpb2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#     <style>
#         #ipyplot-html-viewer-toggle-VtEbZyc36ds7mY6mwPJpBG {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-VtEbZyc36ds7mY6mwPJpBG {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-VtEbZyc36ds7mY6mwPJpBG {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-VtEbZyc36ds7mY6mwPJpBG:checked ~ #ipyplot-html-viewer-textarea-VtEbZyc36ds7mY6mwPJpBG {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-VtEbZyc36ds7mY6mwPJpBG:checked + #ipyplot-html-viewer-label-VtEbZyc36ds7mY6mwPJpBG:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-VtEbZyc36ds7mY6mwPJpBG">
#         <label id="ipyplot-html-viewer-label-VtEbZyc36ds7mY6mwPJpBG" for="ipyplot-html-viewer-toggle-VtEbZyc36ds7mY6mwPJpBG">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-VtEbZyc36ds7mY6mwPJpBG" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-Pm2PqN6PwosFevCKoYzZuG {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Pm2PqN6PwosFevCKoYzZuG {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Pm2PqN6PwosFevCKoYzZuG">
#     <div class="ipyplot-placeholder-div-Pm2PqN6PwosFevCKoYzZuG">
#         <div id="ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG-QdYUswMNvf6gKNjajXFy8s" class="ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/with_tr_jmp_eof1_comp_temp_ampU.png</h4><img src="MATLAB_output/with_tr_jmp_eof1_comp_temp_ampU.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG-QdYUswMNvf6gKNjajXFy8s">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Pm2PqN6PwosFevCKoYzZuG">
#         <div id="ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG-jXkL8DsoJRVSFWFuvGumMk" class="ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">North</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/with_tr_jmp_eof1_comp_temp_ampN.png</h4><img src="MATLAB_output/with_tr_jmp_eof1_comp_temp_ampN.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG-jXkL8DsoJRVSFWFuvGumMk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Pm2PqN6PwosFevCKoYzZuG">
#         <div id="ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG-Vgmmm2eyJ3xrJVdLLACN8G" class="ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">East</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/with_tr_jmp_eof1_comp_temp_ampE.png</h4><img src="MATLAB_output/with_tr_jmp_eof1_comp_temp_ampE.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG-Vgmmm2eyJ3xrJVdLLACN8G">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-Pm2PqN6PwosFevCKoYzZuG {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Pm2PqN6PwosFevCKoYzZuG {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Pm2PqN6PwosFevCKoYzZuG">
#     <div class="ipyplot-placeholder-div-Pm2PqN6PwosFevCKoYzZuG">
#         <div id="ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG-QdYUswMNvf6gKNjajXFy8s" class="ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertical</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/with_tr_jmp_eof1_comp_temp_ampU.png</h4><img src="MATLAB_output/with_tr_jmp_eof1_comp_temp_ampU.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG-QdYUswMNvf6gKNjajXFy8s">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Pm2PqN6PwosFevCKoYzZuG">
#         <div id="ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG-jXkL8DsoJRVSFWFuvGumMk" class="ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">North</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/with_tr_jmp_eof1_comp_temp_ampN.png</h4><img src="MATLAB_output/with_tr_jmp_eof1_comp_temp_ampN.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG-jXkL8DsoJRVSFWFuvGumMk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Pm2PqN6PwosFevCKoYzZuG">
#         <div id="ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG-Vgmmm2eyJ3xrJVdLLACN8G" class="ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">East</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">MATLAB_output/with_tr_jmp_eof1_comp_temp_ampE.png</h4><img src="MATLAB_output/with_tr_jmp_eof1_comp_temp_ampE.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Pm2PqN6PwosFevCKoYzZuG-Vgmmm2eyJ3xrJVdLLACN8G">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
